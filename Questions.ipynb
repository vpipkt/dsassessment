# %% [markdown]
# # Coding Challenges
#
# There are three problems, below, with mandatory tool usage, in parentheses.  Try to complete two of the three problems.  No points are awarded for completion of a third problem.
#
# 1. Data Manipulation (SparkSQL)
# 2. Data Vizualization (Vue, React)
# 3. Data Models (Traditional, Neural Network)
#
# <br>
#
# ### Instructions
#
# * Copy this Jupyter notebook and use it as your turn-in report
#   - there may be multiple notebooks, if a different kernel is used for different tasks
#   - this does not apply to the Data Vizualization task, which should be a zip file
# * Notebook should, at least:
#   - describe the work you've done using markdown (styled as any professional report)
#   - investigate the data and state your assumptions
#   - state results and future work
#   - idempotent - clean up after yourself (i.e. drop your tables)
# * Notebook is scored based upon:
#   - good problem-solving workflow
#   - quality of code
#   - explanation of operations performed beneath code
#   - reproduceability and documentation
#   - professional, interesting, and witty text

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <hr>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # 1. Data Manipulation (SparkSQL)
#
# Use Apache Spark to import the data: `./Data/classification/DM-classification.json`
#
#
# While you MUST use Apache Spark to answer this Data Manipulation question, ANY language (Scala, Pyspark, SparklyR) can be used.

# %% [markdown]
# ### Configure your environment
#
# Please explain this configuration, and why you chose it.

# %%
# Out:
# +--------------------+--------------------+
# |                data|              schema|
# +--------------------+--------------------+
# |[[The battery is ...|[[[index, integer...|
# +--------------------+--------------------+

# %%
df.printSchema()
# Out:
# root
#  |-- data: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- content: string (nullable = true)
#  |    |    |-- index: long (nullable = true)
#  |    |    |-- label: long (nullable = true)
#  |    |    |-- label_1: string (nullable = true)
#  |    |    |-- label_2: string (nullable = true)
#  |    |    |-- label_3: double (nullable = true)
#  |    |    |-- label_4: timestamp (nullable = true)
#  |-- schema: struct (nullable = true)
#  |    |-- fields: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- pandas_version: string (nullable = true)
#  |    |-- primaryKey: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)

# %% [markdown]
# ### ETL
#
# Load the data into a Spark-SQL dataframe with the folowing columns: 'content','label','size','usage','effect','date'.  Create a Temporary Table for querying.
#
# Ensure you use appropriate types with your schema using: StructField, StructType.

# %%
import json


with open(data_file) as f:
  data = json.load(f)
    
type(data)
# Out:
# dict

# %%
data['schema']
# Out:
# {'fields': [{'name': 'index', 'type': 'integer'},
#   {'name': 'content', 'type': 'string'},
#   {'name': 'label', 'type': 'integer'},
#   {'name': 'label_1', 'type': 'string'},
#   {'name': 'label_2', 'type': 'string'},
#   {'name': 'label_3', 'type': 'number'},
#   {'name': 'label_4', 'type': 'datetime'}],
#  'primaryKey': ['index'],
#  'pandas_version': '0.20.0'}

# %%
data['data']
# Out:
# [{'index': 0,
#   'content': 'The battery is completely useless to me.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7155163569,
#   'label_4': '2015-06-05T18:41:08.000Z'},
#  {'index': 1,
#   'content': 'What a big waste of time.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.858630808,
#   'label_4': '2016-10-29T12:12:46.000Z'},
#  {'index': 2,
#   'content': "Don't waste your $$$ on this one.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.2040485858,
#   'label_4': '2016-04-29T14:44:31.000Z'},
#  {'index': 3,
#   'content': 'Great sound and service.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.332641236,
#   'label_4': '2017-12-26T13:25:48.000Z'},
#  {'index': 4,
#   'content': 'Really pleased with this product so far.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.887390017,
#   'label_4': '2016-04-30T00:01:08.000Z'},
#  {'index': 5,
#   'content': 'One of my favorite purchases ever.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.2305351126,
#   'label_4': '2016-04-30T17:29:03.000Z'},
#  {'index': 6,
#   'content': 'best bluetooth on the market.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4549175852,
#   'label_4': '2017-04-24T04:26:54.000Z'},
#  {'index': 7,
#   'content': 'Authentic leather with nice shine and comfort .I recommend you this case !!',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.3198441525,
#   'label_4': '2015-12-16T22:03:11.000Z'},
#  {'index': 8,
#   'content': 'I was very excited to get this headset because I thought it was really cute.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.835863266,
#   'label_4': '2015-05-19T01:34:19.000Z'},
#  {'index': 9,
#   'content': 'Do not make the same mistake as me.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.1442302304,
#   'label_4': '2015-02-03T03:31:18.000Z'},
#  {'index': 10,
#   'content': 'Big Disappointment with calendar sync.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8193389616,
#   'label_4': '2017-11-26T06:01:00.000Z'},
#  {'index': 11,
#   'content': 'the phone was unusable and was not new.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.136951624,
#   'label_4': '2016-10-20T13:10:48.000Z'},
#  {'index': 12,
#   'content': 'Worst Customer Service Ever.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.8700157352,
#   'label_4': '2015-11-09T10:40:50.000Z'},
#  {'index': 13,
#   'content': 'No additional ear gels provided, and no instructions whatsoever.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.719855014,
#   'label_4': '2017-02-17T19:49:15.000Z'},
#  {'index': 14,
#   'content': 'It defeats the purpose of a bluetooth headset.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7345972022,
#   'label_4': '2015-06-22T01:20:10.000Z'},
#  {'index': 15,
#   'content': 'Worth every penny.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5062303093,
#   'label_4': '2017-09-15T10:03:16.000Z'},
#  {'index': 16,
#   'content': 'Excellent wallet type phone case.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.4407609104,
#   'label_4': '2015-06-27T00:04:24.000Z'},
#  {'index': 17,
#   'content': 'Nice headphones for the price and they work great!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.5066209266,
#   'label_4': '2017-01-01T00:32:42.000Z'},
#  {'index': 18,
#   'content': 'Internet is excrutiatingly slow.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.5714815553,
#   'label_4': '2015-02-06T17:18:37.000Z'},
#  {'index': 19,
#   'content': 'It is very comfortable to wear as well, which is probably the most important aspect about using a case.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9208235177,
#   'label_4': '2015-04-30T03:07:00.000Z'},
#  {'index': 20,
#   'content': "It's fits like a glove and is strong, secure, and durable.",
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6738830705,
#   'label_4': '2015-11-20T14:00:43.000Z'},
#  {'index': 21,
#   'content': 'O my gosh the best phone I have ever had.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.5413946605,
#   'label_4': '2015-12-29T15:33:54.000Z'},
#  {'index': 22,
#   'content': "It's very attractive and appears to be of good quality.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.0450112096,
#   'label_4': '2015-04-03T20:39:21.000Z'},
#  {'index': 23,
#   'content': 'I love all the features and form factor.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.7997876288,
#   'label_4': '2017-02-19T23:47:41.000Z'},
#  {'index': 24,
#   'content': 'This product had a strong rubber/petroleum smell that was unbearable after a while and caused me to return it',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5149711935,
#   'label_4': '2016-07-10T11:53:23.000Z'},
#  {'index': 25,
#   'content': 'poor quality and service.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4768013174,
#   'label_4': '2016-09-05T18:08:08.000Z'},
#  {'index': 26,
#   'content': 'The cable looks so thin and flimsy, it is scary.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.3652156041,
#   'label_4': '2017-04-11T17:04:10.000Z'},
#  {'index': 27,
#   'content': 'Great Earpiece.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7035156667,
#   'label_4': '2017-10-11T04:32:32.000Z'},
#  {'index': 28,
#   'content': 'Excellent hands free tool.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4144486516,
#   'label_4': '2016-12-20T15:49:41.000Z'},
#  {'index': 29,
#   'content': 'Great for using with your home stereo.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.3316053728,
#   'label_4': '2017-08-18T12:32:11.000Z'},
#  {'index': 30,
#   'content': 'Good product - incredible value.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4374871642,
#   'label_4': '2015-03-30T10:09:14.000Z'},
#  {'index': 31,
#   'content': "Only had this a month but it's worked flawlessly so far.",
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.2920357021,
#   'label_4': '2016-01-14T14:23:52.000Z'},
#  {'index': 32,
#   'content': 'Works great.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.2336729601,
#   'label_4': '2016-01-12T01:01:02.000Z'},
#  {'index': 33,
#   'content': 'Absolutel junk.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.695451188,
#   'label_4': '2017-12-01T02:42:52.000Z'},
#  {'index': 34,
#   'content': "THAT one didn't work either.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.7206669853,
#   'label_4': '2017-03-01T06:26:07.000Z'},
#  {'index': 35,
#   'content': 'Battery life is real good.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.9909883127,
#   'label_4': '2017-05-11T15:40:08.000Z'},
#  {'index': 36,
#   'content': 'Returned 8 hours later.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.8205248579,
#   'label_4': '2017-08-21T20:24:03.000Z'},
#  {'index': 37,
#   'content': "It's a great item.",
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3757275576,
#   'label_4': '2017-03-08T23:29:13.000Z'},
#  {'index': 38,
#   'content': "Don't waste your money!.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.2237409668,
#   'label_4': '2017-12-31T23:31:02.000Z'},
#  {'index': 39,
#   'content': 'Love this headset!',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.0977322854,
#   'label_4': '2015-02-03T17:23:29.000Z'},
#  {'index': 40,
#   'content': 'Not only will it drain your player, but may also potentially fry it.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7516240366,
#   'label_4': '2015-10-15T12:55:08.000Z'},
#  {'index': 41,
#   'content': 'Worked perfectly!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.5993323014,
#   'label_4': '2017-01-19T19:28:33.000Z'},
#  {'index': 42,
#   'content': "Unreliable - I'm giving up.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.3573437266,
#   'label_4': '2016-12-10T20:24:57.000Z'},
#  {'index': 43,
#   'content': 'I gave it 5 stars because of the sound quality.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.9136805909,
#   'label_4': '2015-05-20T19:20:59.000Z'},
#  {'index': 44,
#   'content': 'Avoid this one if you can.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4711508319,
#   'label_4': '2015-04-05T19:54:09.000Z'},
#  {'index': 45,
#   'content': 'Reversible plug works great.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.2785258572,
#   'label_4': '2016-05-20T02:03:35.000Z'},
#  {'index': 46,
#   'content': 'I wasted my little money with this earpiece.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.8764708481,
#   'label_4': '2017-08-21T18:45:35.000Z'},
#  {'index': 47,
#   'content': 'Very good phone.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.2289094269,
#   'label_4': '2017-07-09T07:19:04.000Z'},
#  {'index': 48,
#   'content': 'Best of all is the rotating feature, very helpful.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.2183598712,
#   'label_4': '2015-07-25T14:18:41.000Z'},
#  {'index': 49,
#   'content': 'Comfort for our whole family.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.9579197625,
#   'label_4': '2017-12-07T06:09:30.000Z'},
#  {'index': 50,
#   'content': 'Good product, good seller.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.7518681839,
#   'label_4': '2016-12-06T20:37:08.000Z'},
#  {'index': 51,
#   'content': 'I love this bluetooth!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4095110932,
#   'label_4': '2015-12-31T07:00:25.000Z'},
#  {'index': 52,
#   'content': "First of all, it doesn't wear well.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.1835077888,
#   'label_4': '2016-08-29T22:31:29.000Z'},
#  {'index': 53,
#   'content': 'I am very impressed with this headset from Plantronics.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.5927933941,
#   'label_4': '2017-07-30T13:32:49.000Z'},
#  {'index': 54,
#   'content': 'I got it because it was so small and adorable.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7317331801,
#   'label_4': '2016-07-26T15:54:51.000Z'},
#  {'index': 55,
#   'content': 'Great phone!.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9349604311,
#   'label_4': '2017-08-09T02:13:19.000Z'},
#  {'index': 56,
#   'content': "I wouldn't recommend buying this product.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5387713624,
#   'label_4': '2017-08-07T01:31:46.000Z'},
#  {'index': 57,
#   'content': 'Piece of Junk.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8372729841,
#   'label_4': '2016-07-27T11:05:21.000Z'},
#  {'index': 58,
#   'content': 'Poorly contstruct hinge.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5400775056,
#   'label_4': '2015-09-30T20:42:38.000Z'},
#  {'index': 59,
#   'content': 'This item is great, installed it, let it charged up overnite and it has been working good every since with no problems',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6523106212,
#   'label_4': '2016-03-28T23:21:38.000Z'},
#  {'index': 60,
#   'content': 'Great Phone.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.3342803226,
#   'label_4': '2015-02-22T02:29:49.000Z'},
#  {'index': 61,
#   'content': "Don't buy it.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.1390373886,
#   'label_4': '2016-08-06T21:34:47.000Z'},
#  {'index': 62,
#   'content': 'Excellent Phone.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.6372055423,
#   'label_4': '2015-05-25T23:14:21.000Z'},
#  {'index': 63,
#   'content': 'DO NOT PURCHASE THIS PHONE.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.4582265117,
#   'label_4': '2016-12-27T13:57:15.000Z'},
#  {'index': 64,
#   'content': 'The voice recognition thru the handset is excellent.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9608068502,
#   'label_4': '2015-12-23T11:28:22.000Z'},
#  {'index': 65,
#   'content': "This is hands down the best phone I've ever had.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.1833412742,
#   'label_4': '2016-11-18T02:48:37.000Z'},
#  {'index': 66,
#   'content': 'Works great, when my cat attacked the phone he scratched the protective strip instead of destroying the screen.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.3443727738,
#   'label_4': '2017-04-14T06:01:40.000Z'},
#  {'index': 67,
#   'content': 'This one works and was priced right.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.54512103,
#   'label_4': '2017-04-21T06:35:02.000Z'},
#  {'index': 68,
#   'content': 'Customer service was terrible.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.0767920429,
#   'label_4': '2017-10-15T03:25:42.000Z'},
#  {'index': 69,
#   'content': 'Battery life still not long enough in Motorola Razor V3i.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7813195245,
#   'label_4': '2016-12-20T15:13:47.000Z'},
#  {'index': 70,
#   'content': 'Sending it back.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6260816889,
#   'label_4': '2017-10-09T11:46:32.000Z'},
#  {'index': 71,
#   'content': 'Now I know that I made a wise decision.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.8569973412,
#   'label_4': '2016-03-28T06:14:47.000Z'},
#  {'index': 72,
#   'content': 'Someone shouldve invented this sooner.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.7013647108,
#   'label_4': '2016-06-26T04:20:22.000Z'},
#  {'index': 73,
#   'content': 'Good price.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.1564291497,
#   'label_4': '2017-11-30T02:25:43.000Z'},
#  {'index': 74,
#   'content': 'Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.441196444,
#   'label_4': '2015-12-27T15:35:34.000Z'},
#  {'index': 75,
#   'content': 'I received it quickly and it works great!!',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.1101205487,
#   'label_4': '2016-08-10T09:16:18.000Z'},
#  {'index': 76,
#   'content': 'Has been working great.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0247731049,
#   'label_4': '2017-07-05T17:31:07.000Z'},
#  {'index': 77,
#   'content': "As many people complained, I found this headset's microphone was very weak.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.8494959223,
#   'label_4': '2017-02-02T23:14:33.000Z'},
#  {'index': 78,
#   'content': 'My 5-year old Nokia 2160 from Tracfone holds the charge a lot better than this.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3972983078,
#   'label_4': '2016-02-22T13:09:45.000Z'},
#  {'index': 79,
#   'content': 'They do not care about the consumer one bit.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.2431707961,
#   'label_4': '2017-05-22T10:39:44.000Z'},
#  {'index': 80,
#   'content': 'This is a good battery, and it got here really fast.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.7552491549,
#   'label_4': '2017-08-17T12:54:43.000Z'},
#  {'index': 81,
#   'content': 'The instruction manual is lacking.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5695787313,
#   'label_4': '2016-03-01T03:18:33.000Z'},
#  {'index': 82,
#   'content': 'Also its slim enough to fit into my alarm clock docking station without removing the case.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.5369593239,
#   'label_4': '2017-10-14T22:58:57.000Z'},
#  {'index': 83,
#   'content': 'Phone now holds charge like it did when it was new.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2599194024,
#   'label_4': '2015-05-10T12:41:15.000Z'},
#  {'index': 84,
#   'content': 'The battery is unreliable as well as the service use antena.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7591447048,
#   'label_4': '2016-10-01T18:40:00.000Z'},
#  {'index': 85,
#   'content': "It's uncomfortable and the sound quality is quite poor compared with the phone (Razr) or with my previous wired headset (that plugged into an LG).",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.2238654911,
#   'label_4': '2016-07-31T10:51:01.000Z'},
#  {'index': 86,
#   'content': 'We have gotten a lot of compliments on it.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.60512665,
#   'label_4': '2016-08-29T19:52:54.000Z'},
#  {'index': 87,
#   'content': 'This is definitely a must have if your state does not allow cell phone usage while driving.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.17128595,
#   'label_4': '2016-05-22T00:51:58.000Z'},
#  {'index': 88,
#   'content': 'I want my money back.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6065003768,
#   'label_4': '2015-07-16T05:30:20.000Z'},
#  {'index': 89,
#   'content': 'I love this device.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.3698600365,
#   'label_4': '2015-02-16T03:54:44.000Z'},
#  {'index': 90,
#   'content': 'I am also very happy with the price.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.478723396,
#   'label_4': '2017-01-27T10:29:15.000Z'},
#  {'index': 91,
#   'content': 'I ordered this product first and was unhappy with it immediately.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5720129366,
#   'label_4': '2015-08-27T19:19:45.000Z'},
#  {'index': 92,
#   'content': 'The Ngage is still lacking in earbuds.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.0166011151,
#   'label_4': '2016-01-13T22:19:46.000Z'},
#  {'index': 93,
#   'content': 'I was able to do voice dialing in the car with no problem.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.9602128894,
#   'label_4': '2015-12-27T22:29:51.000Z'},
#  {'index': 94,
#   'content': 'I have 2-3 bars on my cell phone when I am home, but you cant not hear anything.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.644983618,
#   'label_4': '2015-01-25T16:07:01.000Z'},
#  {'index': 95,
#   'content': 'good item, low price.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.7356360958,
#   'label_4': '2016-11-29T21:09:57.000Z'},
#  {'index': 96,
#   'content': 'However-the riingtones are not the best, and neither are the games.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.4510452412,
#   'label_4': '2017-09-28T18:39:37.000Z'},
#  {'index': 97,
#   'content': 'The plug did not work very well.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.9648187648,
#   'label_4': '2015-11-06T08:50:25.000Z'},
#  {'index': 98,
#   'content': 'AMAZON SUCKS.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4871181913,
#   'label_4': '2015-11-01T04:33:14.000Z'},
#  {'index': 99,
#   'content': 'Rip off---- Over charge shipping.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5392083335,
#   'label_4': '2017-06-30T23:18:32.000Z'},
#  {'index': 100,
#   'content': 'VERY comfortable.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6091511345,
#   'label_4': '2016-12-02T19:09:16.000Z'},
#  {'index': 101,
#   'content': 'The battery is working well as a replacement for the original that came with the phone over 2 years ago.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5883255249,
#   'label_4': '2017-08-27T10:55:10.000Z'},
#  {'index': 102,
#   'content': 'The reception is excellent!',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.6654913664,
#   'label_4': '2017-07-04T10:35:20.000Z'},
#  {'index': 103,
#   'content': 'It fits comfortably in either ear, the sound is clear and loud, and the charge lasts a couple of days.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.9607617638,
#   'label_4': '2016-06-27T01:56:32.000Z'},
#  {'index': 104,
#   'content': "very clear, quality sound and you don't have to mess with the sound on your iPod since you have the sound buttons on the headset.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.9278549193,
#   'label_4': '2015-07-01T23:28:40.000Z'},
#  {'index': 105,
#   'content': "1. long lasting battery (you don't have to recharge it as frequentyly as some of the flip phones)2.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.6789002886,
#   'label_4': '2017-12-02T21:06:06.000Z'},
#  {'index': 106,
#   'content': 'Obviously there is a problem with the adhesive.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.7483711125,
#   'label_4': '2015-04-21T11:13:08.000Z'},
#  {'index': 107,
#   'content': 'Very disappointing.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7299449383,
#   'label_4': '2015-03-15T08:51:21.000Z'},
#  {'index': 108,
#   'content': 'It was an inexpensive piece, but I would still have expected better quality.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.291442398,
#   'label_4': '2016-03-31T17:27:32.000Z'},
#  {'index': 109,
#   'content': 'It is practically useless and did not add any kind of boost to my reception after I bought it.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3084788693,
#   'label_4': '2017-05-21T05:34:43.000Z'},
#  {'index': 110,
#   'content': 'Excellent sound quality.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.4709822316,
#   'label_4': '2015-10-27T13:25:37.000Z'},
#  {'index': 111,
#   'content': 'Was not happy.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.6490008389,
#   'label_4': '2015-04-13T22:58:13.000Z'},
#  {'index': 112,
#   'content': 'A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!!',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.36137606,
#   'label_4': '2015-10-29T20:13:36.000Z'},
#  {'index': 113,
#   'content': 'New Battery works great in phone.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.3573362488,
#   'label_4': '2017-06-24T03:40:55.000Z'},
#  {'index': 114,
#   'content': 'Worst customer service.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.4488168325,
#   'label_4': '2016-05-28T18:45:58.000Z'},
#  {'index': 115,
#   'content': "I've dropped my phone more times than I can say, even on concrete and my phone is still great (knock on wood!).",
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3988212043,
#   'label_4': '2015-04-20T08:01:19.000Z'},
#  {'index': 116,
#   'content': 'Reception is terrible and full of static.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.0769500067,
#   'label_4': '2017-01-28T23:45:53.000Z'},
#  {'index': 117,
#   'content': 'Good audio quality.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.7162965527,
#   'label_4': '2017-04-14T07:35:36.000Z'},
#  {'index': 118,
#   'content': 'This little device has transformed my organizational capability and made my life a whole lot easier.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4183686758,
#   'label_4': '2017-05-22T10:42:51.000Z'},
#  {'index': 119,
#   'content': 'I was sitting in my vehicle, with the cradle on my belt, and the headset lost signal.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8601800143,
#   'label_4': '2015-06-24T03:51:51.000Z'},
#  {'index': 120,
#   'content': 'Were JERKS on the phone.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7049313327,
#   'label_4': '2016-06-06T14:59:45.000Z'},
#  {'index': 121,
#   'content': 'Works like a charm.. Works as advertised.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.8241899475,
#   'label_4': '2016-03-16T11:15:05.000Z'},
#  {'index': 122,
#   'content': 'Comfortable, Nice Range, Good Battery Life.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1889645176,
#   'label_4': '2016-06-18T23:04:58.000Z'},
#  {'index': 123,
#   'content': 'Their network coverage in Los Angeles is horrible.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.9393496582,
#   'label_4': '2017-02-28T19:23:13.000Z'},
#  {'index': 124,
#   'content': 'Excellent starter wireless headset.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.597652376,
#   'label_4': '2017-08-05T23:15:24.000Z'},
#  {'index': 125,
#   'content': 'The loudspeaker option is great, the bumpers with the lights is very ... appealing.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.8921492406,
#   'label_4': '2017-12-08T07:30:06.000Z'},
#  {'index': 126,
#   'content': 'The only thing that I think could improve is the sound leaks out from the headset.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6307713731,
#   'label_4': '2017-07-08T16:33:50.000Z'},
#  {'index': 127,
#   'content': 'First off the reception sucks, I have never had more than 2 bars, ever.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8103378652,
#   'label_4': '2016-07-16T09:53:12.000Z'},
#  {'index': 128,
#   'content': 'The phone gets EXTREMELY HOT!',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.9093805678,
#   'label_4': '2016-01-13T03:58:11.000Z'},
#  {'index': 129,
#   'content': 'The microphone also works well, but (according to people I have called) it applifies everything.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0038533775,
#   'label_4': '2016-01-15T10:58:35.000Z'},
#  {'index': 130,
#   'content': 'Nice design and quality.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7218310908,
#   'label_4': '2017-10-27T14:56:43.000Z'},
#  {'index': 131,
#   'content': 'Also, if your phone is dropped, this case is not going to save it, specially when dropped face down.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.196729987,
#   'label_4': '2015-11-04T14:56:02.000Z'},
#  {'index': 132,
#   'content': 'It is light, easy to use, and has very clear reception and transmission.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.664954299,
#   'label_4': '2017-06-30T02:02:34.000Z'},
#  {'index': 133,
#   'content': 'bad fit, way too big.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.1113521951,
#   'label_4': '2016-06-29T13:54:19.000Z'},
#  {'index': 134,
#   'content': 'It definitely was not as good as my S11.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6996206853,
#   'label_4': '2015-06-16T05:01:13.000Z'},
#  {'index': 135,
#   'content': 'awesome device.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5513468574,
#   'label_4': '2016-05-11T15:13:24.000Z'},
#  {'index': 136,
#   'content': 'Waste of money.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7642316872,
#   'label_4': '2015-12-04T04:11:38.000Z'},
#  {'index': 137,
#   'content': 'I had ordered a motorola data cable, got a very well finished and working product.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.8508537867,
#   'label_4': '2016-11-22T02:04:24.000Z'},
#  {'index': 138,
#   'content': 'Love This Phone.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6432061845,
#   'label_4': '2017-07-02T17:49:27.000Z'},
#  {'index': 139,
#   'content': "I was looking for this headset for a long time and now that I've got it I couldn't be happier.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4467690439,
#   'label_4': '2015-08-03T11:54:59.000Z'},
#  {'index': 140,
#   'content': "I'll be drivng along, and my headset starts ringing for no reason.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.7429297157,
#   'label_4': '2016-02-29T00:16:41.000Z'},
#  {'index': 141,
#   'content': 'Display is excellent and camera is as good as any from that year.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5816913221,
#   'label_4': '2016-04-27T20:59:24.000Z'},
#  {'index': 142,
#   'content': 'Battery life is also great!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4180942904,
#   'label_4': '2016-04-24T15:31:22.000Z'},
#  {'index': 143,
#   'content': "The worst phone I've ever had.... Only had it for a few months.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.0792309642,
#   'label_4': '2015-01-07T08:06:06.000Z'},
#  {'index': 144,
#   'content': 'Not a good item.. It worked for a while then started having problems in my auto reverse tape player.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.977568549,
#   'label_4': '2016-10-20T23:57:54.000Z'},
#  {'index': 145,
#   'content': 'This is so embarassing and also my ears hurt if I try to push the ear plug into my ear.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.3492527829,
#   'label_4': '2015-04-29T12:26:42.000Z'},
#  {'index': 146,
#   'content': 'Protects the phone on all sides.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.3096174508,
#   'label_4': '2017-02-17T08:13:30.000Z'},
#  {'index': 147,
#   'content': 'This is a VERY average phone with bad battery life that operates on a weak network.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9805991898,
#   'label_4': '2017-02-18T01:03:26.000Z'},
#  {'index': 148,
#   'content': 'Clear Skype Calls, Long Battery Life, Long Range.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.3739072159,
#   'label_4': '2015-02-21T23:32:43.000Z'},
#  {'index': 149,
#   'content': 'Soyo technology sucks.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.0316237936,
#   'label_4': '2016-07-16T07:57:47.000Z'},
#  {'index': 150,
#   'content': 'Great Hands Free Device.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9667161592,
#   'label_4': '2015-12-19T02:24:41.000Z'},
#  {'index': 151,
#   'content': 'you can even take self portraits with the outside (exterior) display, very cool.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4739650913,
#   'label_4': '2017-05-24T18:02:41.000Z'},
#  {'index': 152,
#   'content': 'Same problem as others have mentioned.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8219304954,
#   'label_4': '2016-05-14T01:30:40.000Z'},
#  {'index': 153,
#   'content': 'After trying many many handsfree gadgets this is the one that finally works well.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.8993581627,
#   'label_4': '2015-12-01T22:34:46.000Z'},
#  {'index': 154,
#   'content': 'Magical Help.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.7715440127,
#   'label_4': '2015-11-24T16:37:39.000Z'},
#  {'index': 155,
#   'content': 'The worst piece of crap ever along with the Verizon customer service.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4603957511,
#   'label_4': '2015-02-20T05:27:09.000Z'},
#  {'index': 156,
#   'content': 'Poor sound quality.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7540434837,
#   'label_4': '2016-01-23T10:39:20.000Z'},
#  {'index': 157,
#   'content': 'The best phone in market :).',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.0128824344,
#   'label_4': '2015-11-16T20:14:50.000Z'},
#  {'index': 158,
#   'content': 'It worked very well.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7962515995,
#   'label_4': '2016-09-08T01:47:00.000Z'},
#  {'index': 159,
#   'content': 'The company shipped my product very promptly and it works well.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.4957837328,
#   'label_4': '2017-12-20T12:15:44.000Z'},
#  {'index': 160,
#   'content': 'Exactly what I wanted.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5041422715,
#   'label_4': '2015-09-21T15:28:17.000Z'},
#  {'index': 161,
#   'content': 'The picture resolution is far below what other comparably-priced phones are offering today.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.4176583273,
#   'label_4': '2016-10-08T18:35:10.000Z'},
#  {'index': 162,
#   'content': 'This is a great deal.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8797092871,
#   'label_4': '2017-07-18T16:53:36.000Z'},
#  {'index': 163,
#   'content': 'Excellent product, I am very satisfied with the purchase.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.2917226538,
#   'label_4': '2017-02-24T13:30:01.000Z'},
#  {'index': 164,
#   'content': 'I highly recommend these and encourage people to give them a try.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4467386209,
#   'label_4': '2015-11-23T11:47:37.000Z'},
#  {'index': 165,
#   'content': "Better than you'd expect.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.049132322,
#   'label_4': '2015-01-01T23:54:55.000Z'},
#  {'index': 166,
#   'content': 'Using all earpieces, left or right, this thing will not stay on my ear.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0890445502,
#   'label_4': '2016-06-09T05:48:19.000Z'},
#  {'index': 167,
#   'content': 'Great product and price.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7715442232,
#   'label_4': '2017-02-26T12:59:37.000Z'},
#  {'index': 168,
#   'content': 'Sounds good reasonably priced and effective, Its that simple !',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.5860310696,
#   'label_4': '2015-07-03T03:26:44.000Z'},
#  {'index': 169,
#   'content': "Still Waiting...... I'm sure this item would work well.. if I ever recieve it!",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.977861435,
#   'label_4': '2016-10-12T02:41:02.000Z'},
#  {'index': 170,
#   'content': 'what a disappointment',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.3199215979,
#   'label_4': '2016-12-13T10:15:05.000Z'},
#  {'index': 171,
#   'content': 'Very prompt service.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1398449621,
#   'label_4': '2017-10-22T01:02:22.000Z'},
#  {'index': 172,
#   'content': 'Excellent product for the price.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.6570487571,
#   'label_4': '2016-08-11T22:12:55.000Z'},
#  {'index': 173,
#   'content': 'Very pleased with this headset.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.6986507808,
#   'label_4': '2017-08-22T11:43:42.000Z'},
#  {'index': 174,
#   'content': "don't waste your money and time.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.1851550926,
#   'label_4': '2016-11-06T22:58:07.000Z'},
#  {'index': 175,
#   'content': 'I especially love the long battery life.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4553956566,
#   'label_4': '2017-06-18T05:14:23.000Z'},
#  {'index': 176,
#   'content': "It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.8979672157,
#   'label_4': '2017-01-17T09:44:49.000Z'},
#  {'index': 177,
#   'content': 'Works great.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.2762001919,
#   'label_4': '2015-10-15T00:51:34.000Z'},
#  {'index': 178,
#   'content': 'Plantronics Bluetooth Excelent Buy.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.507661411,
#   'label_4': '2016-02-04T03:03:02.000Z'},
#  {'index': 179,
#   'content': 'I came over from Verizon because cingulair has nicer cell phones.... the first thing I noticed was the really bad service.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6233705443,
#   'label_4': '2015-02-02T18:22:02.000Z'},
#  {'index': 180,
#   'content': "I'll be looking for a new earpiece.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.6623023642,
#   'label_4': '2015-03-04T08:12:21.000Z'},
#  {'index': 181,
#   'content': 'I highly recommend this device to everyone!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0884018558,
#   'label_4': '2016-05-11T08:09:48.000Z'},
#  {'index': 182,
#   'content': 'Jawbone Era is awesome too!',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.1049665375,
#   'label_4': '2017-04-24T04:24:31.000Z'},
#  {'index': 183,
#   'content': 'We received a WHITE colored battery that goes DEAD after a couple hoursTHe original used to last a week - but still lasts longer than thereplacement',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.6128416199,
#   'label_4': '2017-01-13T11:40:59.000Z'},
#  {'index': 184,
#   'content': 'After a year the battery went completely dead on my headset.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.2194879268,
#   'label_4': '2015-07-30T10:33:54.000Z'},
#  {'index': 185,
#   'content': 'I have used several phone in two years, but this one is the best.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.3094529154,
#   'label_4': '2017-07-17T12:22:19.000Z'},
#  {'index': 186,
#   'content': 'An Awesome New Look For Fall 2000!.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.1738125025,
#   'label_4': '2015-07-26T12:54:22.000Z'},
#  {'index': 187,
#   'content': "This is the first phone I've had that has been so cheaply made.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.9933623601,
#   'label_4': '2017-01-08T03:29:51.000Z'},
#  {'index': 188,
#   'content': 'Att is not clear, sound is very distorted and you have to yell when you talk.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.6766335124,
#   'label_4': '2017-03-29T12:30:01.000Z'},
#  {'index': 189,
#   'content': 'The plastic breaks really easy on this clip.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.2925907882,
#   'label_4': '2015-11-22T15:01:29.000Z'},
#  {'index': 190,
#   'content': 'Price is good too.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.7852313162,
#   'label_4': '2017-11-08T04:19:46.000Z'},
#  {'index': 191,
#   'content': "Don't make the same mistake I did.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1923718699,
#   'label_4': '2016-03-13T10:59:12.000Z'},
#  {'index': 192,
#   'content': 'Oh and I forgot to also mention the weird color effect it has on your phone.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4479888513,
#   'label_4': '2016-11-07T23:36:04.000Z'},
#  {'index': 193,
#   'content': "I'm using it with an iriver SPINN (with case) and it fits fine.",
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.7670933958,
#   'label_4': '2016-01-09T07:50:08.000Z'},
#  {'index': 194,
#   'content': "Also the area where my unit broke).- I'm not too fond of the magnetic strap.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0903860442,
#   'label_4': '2017-12-10T02:25:13.000Z'},
#  {'index': 195,
#   'content': 'Overall, I am psyched to have a phone which has all my appointments and contacts in and gets great reception.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.0033464393,
#   'label_4': '2015-12-20T02:31:12.000Z'},
#  {'index': 196,
#   'content': 'every thing on phone work perfectly, she like it.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.9239969702,
#   'label_4': '2016-01-23T05:12:15.000Z'},
#  {'index': 197,
#   'content': "Another note about this phone's appearance is that it really looks rather bland, especially in the all black model.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3187068105,
#   'label_4': '2017-08-15T03:37:22.000Z'},
#  {'index': 198,
#   'content': "IT'S REALLY EASY.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.2896892238,
#   'label_4': '2017-04-20T16:55:42.000Z'},
#  {'index': 199,
#   'content': 'My Sanyo has survived dozens of drops on blacktop without ill effect.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.2472987108,
#   'label_4': '2016-08-27T17:39:22.000Z'},
#  {'index': 200,
#   'content': 'Fantastic earphones.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2048449665,
#   'label_4': '2017-05-25T07:05:03.000Z'},
#  {'index': 201,
#   'content': 'It finds my cell phone right away when I enter the car.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1936607622,
#   'label_4': '2016-06-05T03:15:17.000Z'},
#  {'index': 202,
#   'content': 'Low Quality.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.816960336,
#   'label_4': '2016-10-28T10:01:40.000Z'},
#  {'index': 203,
#   'content': 'I highly recommend this modest priced cellular phone.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.3523032105,
#   'label_4': '2017-09-07T09:00:14.000Z'},
#  {'index': 204,
#   'content': "But it does get better reception and clarity than any phone I've had before.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.5533041622,
#   'label_4': '2017-06-18T16:36:33.000Z'},
#  {'index': 205,
#   'content': 'Warning - Stay away.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3076290526,
#   'label_4': '2016-11-06T20:09:59.000Z'},
#  {'index': 206,
#   'content': 'I wish I could return the unit and get back my money.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.4739659317,
#   'label_4': '2016-06-04T23:26:47.000Z'},
#  {'index': 207,
#   'content': 'Awsome Device Works Great!!.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6444913309,
#   'label_4': '2016-04-07T04:11:56.000Z'},
#  {'index': 208,
#   'content': 'I used to talk on it for 1 - 1 1/2 hours and the battery would be literally drained and dying.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.0958905732,
#   'label_4': '2015-09-21T06:25:53.000Z'},
#  {'index': 209,
#   'content': "If you don't find it, too bad, as again the unit comes with one earpad only.I would not recommend this to anyone.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5226929814,
#   'label_4': '2017-05-18T02:12:03.000Z'},
#  {'index': 210,
#   'content': 'Very Displeased.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.2659266983,
#   'label_4': '2017-03-18T18:26:54.000Z'},
#  {'index': 211,
#   'content': 'I might have gotten a defect, but I would not risk buying it again because of the built quality alone.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2830689464,
#   'label_4': '2017-09-21T17:36:05.000Z'},
#  {'index': 212,
#   'content': 'They made this case too small and is very difficult to install.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.0433855809,
#   'label_4': '2016-11-10T04:32:29.000Z'},
#  {'index': 213,
#   'content': 'Restored my phone to like new performance.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.884474552,
#   'label_4': '2016-11-06T22:31:38.000Z'},
#  {'index': 214,
#   'content': 'I would recommend purchasing the Jabra JX-10 series 2 which works flawlessly with my Moto Q, go figure.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.7612339325,
#   'label_4': '2017-09-22T17:16:05.000Z'},
#  {'index': 215,
#   'content': 'I searched the Internet, and found this one to be the best value.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4917072583,
#   'label_4': '2017-08-22T14:13:33.000Z'},
#  {'index': 216,
#   'content': 'Does not fit.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0362115766,
#   'label_4': '2016-12-06T10:22:28.000Z'},
#  {'index': 217,
#   'content': 'Very happy with this product.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.1406284045,
#   'label_4': '2017-09-14T19:53:54.000Z'},
#  {'index': 218,
#   'content': 'The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.8384375899,
#   'label_4': '2017-12-27T09:34:23.000Z'},
#  {'index': 219,
#   'content': "There's really nothing bad I can say about this headset.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.703499022,
#   'label_4': '2017-04-23T11:56:27.000Z'},
#  {'index': 220,
#   'content': "i'm glad i found this product on amazon it is hard to find, it wasn't high priced.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.1705451992,
#   'label_4': '2017-06-20T14:29:14.000Z'},
#  {'index': 221,
#   'content': 'Portable and it works.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7768697115,
#   'label_4': '2016-06-18T17:38:47.000Z'},
#  {'index': 222,
#   'content': 'My colleague & I now get great reception.A little expensive, but performance is great.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0044321272,
#   'label_4': '2016-04-27T10:42:11.000Z'},
#  {'index': 223,
#   'content': 'I even fully charged it before I went to bed and turned off blue tooth and wi-fi and noticed that it only had 20 % left in the morning.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.7623023205,
#   'label_4': '2015-03-31T21:55:07.000Z'},
#  {'index': 224,
#   'content': "I've also had problems with the phone reading the memory card in which I always turn it on and then off again.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.942537363,
#   'label_4': '2015-05-08T05:50:48.000Z'},
#  {'index': 225,
#   'content': 'Not good when wearing a hat or sunglasses.',
# ...
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0678565615,
#   'label_4': '2016-11-05T04:08:25.000Z'},
#  {'index': 927,
#   'content': 'This item is fantastic and works perfectly!',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.4312482833,
#   'label_4': '2015-06-05T19:50:58.000Z'},
#  {'index': 928,
#   'content': 'And I just love the colors!',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2165723152,
#   'label_4': '2016-12-08T17:03:21.000Z'},
#  {'index': 929,
#   'content': 'W810i is just SUPERB.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.1702454553,
#   'label_4': '2016-11-05T07:02:56.000Z'},
#  {'index': 930,
#   'content': 'All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0809010745,
#   'label_4': '2016-10-08T14:04:37.000Z'},
#  {'index': 931,
#   'content': 'Great charger.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0481119667,
#   'label_4': '2017-06-29T13:30:33.000Z'},
#  {'index': 932,
#   'content': 'This is essentially a communications tool that does not communicate.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7795990833,
#   'label_4': '2017-04-29T02:51:58.000Z'},
#  {'index': 933,
#   'content': 'Works like a charm; it work the same as the one I got with the phone.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.1161557531,
#   'label_4': '2015-08-30T00:09:47.000Z'},
#  {'index': 934,
#   'content': "I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5863107024,
#   'label_4': '2015-10-18T06:35:38.000Z'},
#  {'index': 935,
#   'content': 'Great Value.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.8571447148,
#   'label_4': '2016-11-03T12:17:10.000Z'},
#  {'index': 936,
#   'content': "Doesn't work at all.. I bougth it for my L7c and its not working.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.3582617505,
#   'label_4': '2015-09-26T07:08:56.000Z'},
#  {'index': 937,
#   'content': 'The look of it is very sharp and the screen is nice and clear, with great graphics.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.8083880189,
#   'label_4': '2016-11-02T03:35:46.000Z'},
#  {'index': 938,
#   'content': "doesn't last long.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.9309495638,
#   'label_4': '2015-10-06T03:24:00.000Z'},
#  {'index': 939,
#   'content': 'One thing I hate is the mode set button at the side.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.9485154929,
#   'label_4': '2016-10-19T07:51:52.000Z'},
#  {'index': 940,
#   'content': 'EXCELLENT SERVICE!!!!!!!!.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.6684907436,
#   'label_4': '2015-01-14T23:04:14.000Z'},
#  {'index': 941,
#   'content': 'Thank you for wasting my money.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.9520367577,
#   'label_4': '2017-03-03T21:16:29.000Z'},
#  {'index': 942,
#   'content': 'How can that be?The audio quality is poor.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7546769889,
#   'label_4': '2017-04-15T18:50:21.000Z'},
#  {'index': 943,
#   'content': 'The iGo chargers and tips are really great.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4371464085,
#   'label_4': '2015-05-27T22:54:13.000Z'},
#  {'index': 944,
#   'content': 'The file browser offers all the options that one needs.Handsfree is great.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.3479720923,
#   'label_4': '2017-04-30T12:59:42.000Z'},
#  {'index': 945,
#   'content': 'Superb Phone on a Great Network.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.4776414318,
#   'label_4': '2016-02-03T11:24:00.000Z'},
#  {'index': 946,
#   'content': "I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case.",
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.7187870496,
#   'label_4': '2016-07-23T18:45:20.000Z'},
#  {'index': 947,
#   'content': 'I put the latest OS on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.1835306488,
#   'label_4': '2015-02-28T09:38:52.000Z'},
#  {'index': 948,
#   'content': 'It only recognizes the Phone as its storage device.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.8851823473,
#   'label_4': '2017-08-10T09:53:18.000Z'},
#  {'index': 949,
#   'content': 'If you like a loud buzzing to override all your conversations, then this phone is for you!',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.7958130847,
#   'label_4': '2016-12-04T12:19:03.000Z'},
#  {'index': 950,
#   'content': "Don't buy this product.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.197275582,
#   'label_4': '2017-11-21T22:04:11.000Z'},
#  {'index': 951,
#   'content': "I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.",
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1634594061,
#   'label_4': '2016-02-06T19:21:25.000Z'},
#  {'index': 952,
#   'content': 'The sound quality is good and functionality is awesome.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5694131258,
#   'label_4': '2015-01-14T18:13:39.000Z'},
#  {'index': 953,
#   'content': 'I have this phone and it is a thorn in my side, I really abhor it.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6618369794,
#   'label_4': '2017-06-10T19:27:54.000Z'},
#  {'index': 954,
#   'content': 'I recently had problems where I could not stay connected for more than 10 minutes before being disconnected.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.8810077311,
#   'label_4': '2017-07-24T03:56:26.000Z'},
#  {'index': 955,
#   'content': 'Incredible!.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.1408272905,
#   'label_4': '2017-04-25T11:33:21.000Z'},
#  {'index': 956,
#   'content': 'Design Flaw?.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.7378991521,
#   'label_4': '2015-08-21T20:13:31.000Z'},
#  {'index': 957,
#   'content': 'Great phone!.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.041066254,
#   'label_4': '2016-10-16T16:23:35.000Z'},
#  {'index': 958,
#   'content': 'Waste of 13 bucks.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.0134839595,
#   'label_4': '2016-08-06T22:02:39.000Z'},
#  {'index': 959,
#   'content': "But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6629752723,
#   'label_4': '2015-07-19T06:36:53.000Z'},
#  {'index': 960,
#   'content': 'The replacement died in a few weeks.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.5090480086,
#   'label_4': '2017-06-20T12:20:06.000Z'},
#  {'index': 961,
#   'content': 'Any ring tone..Overall good phone to buy..',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.3330156641,
#   'label_4': '2017-10-07T03:40:19.000Z'},
#  {'index': 962,
#   'content': 'Lately they have been extremely nice and helpful on the phone.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5697585049,
#   'label_4': '2015-11-18T15:13:17.000Z'},
#  {'index': 963,
#   'content': 'I have had problems wit hit dropping signal and more.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.135539506,
#   'label_4': '2017-06-26T08:08:24.000Z'},
#  {'index': 964,
#   'content': 'Not impressed.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.7925837658,
#   'label_4': '2016-02-14T11:02:20.000Z'},
#  {'index': 965,
#   'content': 'Light weight, I hardly notice it is there.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.4133420385,
#   'label_4': '2015-02-02T14:57:52.000Z'},
#  {'index': 966,
#   'content': "You'll love how thin it is.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2858438637,
#   'label_4': '2016-07-04T18:40:27.000Z'},
#  {'index': 967,
#   'content': 'Bad Choice.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.5661402021,
#   'label_4': '2016-02-09T17:36:11.000Z'},
#  {'index': 968,
#   'content': "The pleather case doesn't fit.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.8049254841,
#   'label_4': '2016-08-10T10:42:47.000Z'},
#  {'index': 969,
#   'content': 'useless phone, simply deaf.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.9555489248,
#   'label_4': '2017-02-21T11:10:06.000Z'},
#  {'index': 970,
#   'content': 'The color is even prettier than I thought it would be, and the graphics are incredibly sharp.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.1147092621,
#   'label_4': '2016-02-26T02:34:55.000Z'},
#  {'index': 971,
#   'content': 'All in all I think it was a good investment.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6652142843,
#   'label_4': '2017-03-09T14:10:27.000Z'},
#  {'index': 972,
#   'content': 'It makes very strange ticking noises before it ends the call.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.0943706918,
#   'label_4': '2016-10-17T09:09:27.000Z'},
#  {'index': 973,
#   'content': 'The best electronics of the available FM Transmitters.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.6713082135,
#   'label_4': '2017-11-20T10:01:59.000Z'},
#  {'index': 974,
#   'content': 'Battery lasts only a few hours.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.8737485869,
#   'label_4': '2016-11-25T05:53:48.000Z'},
#  {'index': 975,
#   'content': 'great headset, very impressed - H500.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.6447723393,
#   'label_4': '2016-08-19T18:25:59.000Z'},
#  {'index': 976,
#   'content': 'The "1.2" mega pixel camera, being a part of a phone, is reasonably good7.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.8147385391,
#   'label_4': '2017-09-30T08:29:50.000Z'},
#  {'index': 977,
#   'content': "I've had this for nearly 2 years and it has worked great for me.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.2201515622,
#   'label_4': '2017-07-11T22:36:10.000Z'},
#  {'index': 978,
#   'content': 'Good transmit audio.',
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.2066701947,
#   'label_4': '2017-09-06T23:53:58.000Z'},
#  {'index': 979,
#   'content': 'We are sending it back.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5419181135,
#   'label_4': '2017-04-05T16:36:49.000Z'},
#  {'index': 980,
#   'content': 'I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.6409394458,
#   'label_4': '2017-12-23T11:50:39.000Z'},
#  {'index': 981,
#   'content': 'If you hate earbugs, avoid this phone by all means.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.1124697659,
#   'label_4': '2017-01-12T16:47:50.000Z'},
#  {'index': 982,
#   'content': 'Great price also!',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.4526761397,
#   'label_4': '2017-02-28T08:29:32.000Z'},
#  {'index': 983,
#   'content': "The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.0240287714,
#   'label_4': '2015-01-28T01:30:35.000Z'},
#  {'index': 984,
#   'content': 'fast service.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.3616442919,
#   'label_4': '2015-12-27T12:00:59.000Z'},
#  {'index': 985,
#   'content': 'I would highly recommend this.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.3054161132,
#   'label_4': '2015-03-04T21:48:05.000Z'},
#  {'index': 986,
#   'content': 'I would recommend this.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.6846847056,
#   'label_4': '2016-09-11T14:17:51.000Z'},
#  {'index': 987,
#   'content': 'I also didn\'t like the "on" button, it felt like it would crack with use.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'conected',
#   'label_3': 0.5757797224,
#   'label_4': '2016-03-11T23:11:40.000Z'},
#  {'index': 988,
#   'content': 'WORST PHONE EVER.',
#   'label': 0,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.1031288312,
#   'label_4': '2017-12-27T12:35:10.000Z'},
#  {'index': 989,
#   'content': "I'm still infatuated with this phone.",
#   'label': 1,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.4989944719,
#   'label_4': '2017-05-28T06:24:41.000Z'},
#  {'index': 990,
#   'content': 'Freezes frequently4.',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.444585281,
#   'label_4': '2016-06-16T21:31:10.000Z'},
#  {'index': 991,
#   'content': "It's kind of embarrassing to use because of how it looks and mostly it's embarrassing how child-like the company is.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.0113410372,
#   'label_4': '2015-05-04T03:17:25.000Z'},
#  {'index': 992,
#   'content': 'Simple, lightweight and great fit.',
#   'label': 1,
#   'label_1': 'small',
#   'label_2': 'separate',
#   'label_3': 0.5256624138,
#   'label_4': '2017-09-09T22:37:13.000Z'},
#  {'index': 993,
#   'content': "All in all, I'd expected a better consumer experience from Motorola.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'conected',
#   'label_3': 0.0309532493,
#   'label_4': '2015-11-12T07:17:25.000Z'},
#  {'index': 994,
#   'content': "There's a horrible tick sound in the background on all my calls that I have never experienced before.",
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.1980547769,
#   'label_4': '2015-06-26T21:08:51.000Z'},
#  {'index': 995,
#   'content': 'These are certainly very comfortable and functionality is decent.',
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.0425101461,
#   'label_4': '2017-01-09T12:23:24.000Z'},
#  {'index': 996,
#   'content': "I usually don't like headbands but this one is very lightweight & doesn't mess up my hair.",
#   'label': 1,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.5156241173,
#   'label_4': '2016-07-04T09:21:03.000Z'},
#  {'index': 997,
#   'content': "I'm a bit disappointed.",
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'conected',
#   'label_3': 0.069515645,
#   'label_4': '2016-11-01T14:19:24.000Z'},
#  {'index': 998,
#   'content': 'I have had this phone for over a year now, and I will tell you, its not that great.',
#   'label': 0,
#   'label_1': 'medium',
#   'label_2': 'separate',
#   'label_3': 0.5153000368,
#   'label_4': '2017-07-08T02:14:40.000Z'},
#  {'index': 999,
#   'content': 'I ordered this for sony Ericsson W810i but I think it only worked once (thats when I first used it).',
#   'label': 0,
#   'label_1': 'large',
#   'label_2': 'separate',
#   'label_3': 0.6311659385,
#   'label_4': '2017-02-25T20:21:54.000Z'}]

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('fda') \
    .getOrCreate()

data_file = './Data/classification/DM-classification.json'

df = spark.read.json(data_file)

df.show()
# Out:
# +--------------------+--------------------+
# |                data|              schema|
# +--------------------+--------------------+
# |[[The battery is ...|[[[index, integer...|
# +--------------------+--------------------+

# %%
sql = SQLContext(sc)
df = sql.read.json(data_file)

# %% [markdown]
# ### Process
#
# Group the table by 'size', and sort based on 'date'.  Then, create a new column that is the difference between 'date' in consecutive records (within groups).

# %% [markdown]
# ### Save
#
# Save the data results as one file.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <hr>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # 2. Data Visualization (Vue, React)
#
# Design and build a User Interface to visualize the data: `./Data/classification/DV-classification.json`
#
#
# Please be creative in your design, but meet the following requirements:
#
# * enable it to be deployed using docker: `docker run`
# * use either Vue, React, or complimentary framework (ie. Nuxt, Next)
# * use a styling library of your choice
# * add some basic interactivity to explore the data, such as [dc.js](https://dc-js.github.io/dc.js/)
# * explain how this would be deployed, including the necessary tools and hardware
#
# Send this solution via a zipped directory, and include instructions.
#
# ![example interface](./Data/classification/image-DimChart.png)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <hr>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # 3. Data Models
#
# __Note:__ this task is language and framework agnostic.

# %% [markdown]
# ## Models: Traditional Methods
#
# This section will make use of traditional analytic methods to describe and model the data.  It will NOT make use of Neural Network - based methods.

# %% [markdown]
# ### Import data and summarize
#
# Import the classification data: `./Data/classification/classification.txt` into two columns: 'content', 'labels'.  Review and summarize the data.  Make any notes of your observations.

# %% [markdown]
# ### Preprocessing
#
# Create preprocessing function that does the following:
#
# * lowercase text
# * replace punctuation, digits, & all special characters except '_' underscore with one space
#
# Preprocess 'content' column, and store prepped content in a new column called 'prep_content'.

# %% [markdown]
# ### Dataset dev(train, validate)-test split
#
# Make dev_train, dev_validate, and test sets with dev_validate and test sets being the same size.

# %% [markdown]
# ### Named Entity Recognition
#
# Count how many organizations -- 'ORG' exist in the `dev_train` dataset.  Use a text processing framework with included NER classifier to perform this.

# %% [markdown]
# ### ML pipeline with logistic regression
#
# Build a ML Pipeline that performs the following:
#
# * vectorizes text
# * selects top 100 features with chi2
# * trains a logistic regression classifier

# %% [markdown]
# ### Pipeline inspection
#
# Review the pipeline and print the 100 features that the chi2 selector chose along with each feature's score.

# %% [markdown]
# ### Model
#
# Plot the learning curve.

# %% [markdown]
# ### Discuss future work
#
# Make notes of the learning curve and discuss how it effects your future work in this modeling process.

# %% [markdown]
# ## Models: Neural Network Methods
#
# This section will make use of Neural Network - based methods, including word embeddings.  You MUST use a neural network (NN) framework (PyTorch, DeepLearning4J, MXNet, Keras, TensorFlow, etc) for performing these tasks.
#
# While you will not be judged on the accuracy of the model, the architecture should be appropriate for the situation.

# %% [markdown]
# ### Configure environment
#
# Prepare your environment for your NN framwork of choice, and with the ability to reproduce your results.
#
# Also, explain your platform and how different hardware might provide improvements to your code.

# %% [markdown]
# ### Re-ETL and dataset split
#
# Reformat the original data for ingestion with your NN framework.  Be sure to explain how the process relates to your framework.
#
# Ensure that you re-split the data, also.

# %% [markdown]
# ### Word embeddings
#
# Apply word embedding and explain their purpose with respect to the traditional methods used, above.
#
# Explain the underlying concepts of word embeddings with an example.

# %% [markdown]
# ### Model architecture
#
# Determine an architecture for your neural network classifier.  Explain why you chose the architecture, then implement it in your chosen framework.
#
# Be sure to initialize the model, and print the number of parameters.

# %% [markdown]
# ### Model training routine
#
# What decisions do you have to make for training the model.  Ensure you include the following:
#
# * loss function
# * scoring criteria
# * optimization
#
# Explain why these were chosen and implement them in code.

# %% [markdown]
# ### Train and evaluate
#
# Train the model and evaluate the results.
#
# Ensure that you print some of the Training and Validation scores that you decided upon, after each iteration / epoch.

# %% [markdown]
# ### Spark integration
#
# Explain how you would train and apply this model on a large dataset that required a Spark cluster to process.
